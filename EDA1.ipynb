# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmaMills1002/DS-3001-Project/blob/main/CovidCleanedCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df.head()
# Out:
#    id region of residence  age of subject  time spent on online class  \
# 0  R1           Delhi-NCR              21                         2.0
# 1  R2           Delhi-NCR              21                         0.0
# 2  R3           Delhi-NCR              20                         7.0
# 3  R4           Delhi-NCR              20                         3.0
# 4  R5           Delhi-NCR              21                         3.0
#
#   rating of online class experience medium for online class  \
# 0                              Good          Laptop/Desktop
# 1                         Excellent              Smartphone
# 2                         Very poor          Laptop/Desktop
# 3                         Very poor              Smartphone
# 4                              Good          Laptop/Desktop
#
#    time spent on self study  time spent on fitness  time spent on sleep  \
# 0                       4.0                    0.0                  7.0
# ...

# %%
df['age of subject'].hist(bins=33,grid=False)
# Out:
# <Axes: >

# %%
df["time spent on fitness"].hist(bins=33, grid=False)
# Out:
# <Axes: >

# %%
df["time spent on self study"].hist(bins=33, grid=False)
# Out:
# <Axes: >

# %%
df["time spent on social media"].hist(bins=33, grid=False)
# Out:
# <Axes: >

# %%
df.plot.scatter( y='age of subject',x='time spent on online class')
df.plot.scatter( y='age of subject',x='time spent on fitness')
df.plot.scatter( y='age of subject',x='time spent on self study')
# Out:
# <Axes: xlabel='time spent on self study', ylabel='age of subject'>

# %%
group_by = df['rating of online class experience']
var = df['time spent on online class']
df_wide = df.pivot(columns=group_by,values=var)
#df_wide.plot.density()

#df_wide.loc[:,['A','B','W']].plot.density()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Good'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 3
# ...

# %%
import seaborn as sns
sns.scatterplot(x=df['time spent on online class'], y=df['time spent on self study'], hue=df['rating of online class experience'])
# Out:
# <Axes: xlabel='time spent on online class', ylabel='time spent on self study'>

# %%
sns.scatterplot(x=df['time spent on online class'], y=df['time spent on self study'], hue=df['medium for online class'])
# Out:
# <Axes: xlabel='time spent on online class', ylabel='time spent on self study'>

# %%
sns.scatterplot(x=df['time spent on online class'], y=df['time spent on self study'], hue=df['medium for online class'])

# %%
sns.scatterplot(x=df['time spent on online class'], y=df['time spent on self study'], hue=df['do you find yourself more connected with your family, close friends , relatives  ?'])
# Out:
# <Axes: xlabel='time spent on online class', ylabel='time spent on self study'>

# %%
sns.scatterplot(x=df['time spent on online class'], y=df['time spent on self study'], hue=df['health issue during lockdown'])
# Out:
# <Axes: xlabel='time spent on online class', ylabel='time spent on self study'>

# %%
sns.scatterplot(x=df['time spent on fitness'], y=df['time spent on sleep'], hue=df['health issue during lockdown'])
# Out:
# <Axes: xlabel='time spent on fitness', ylabel='time spent on sleep'>

# %%
sns.scatterplot(x=df['time spent on fitness'], y=df['number of meals per day'], hue=df['change in your weight'])
# Out:
# <Axes: xlabel='time spent on fitness', ylabel='number of meals per day'>

# %%
sns.scatterplot(x=df['time spent on online class'], y=df['number of meals per day'], hue=df['change in your weight'])
# Out:
# <Axes: xlabel='time spent on online class', ylabel='number of meals per day'>

# %%
sns.scatterplot(x=df['time spent on self study'], y=df['number of meals per day'], hue=df['change in your weight'])
# Out:
# <Axes: xlabel='time spent on self study', ylabel='number of meals per day'>
